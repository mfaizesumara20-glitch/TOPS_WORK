# %%
import pandas as pd

employees = {

    'name': ['faize','alan','amiy'],
    'age': [20,25,26 ],
    'salary': [15000,16000,17000]
}

res = pd.DataFrame(employees)
print(res)
# Out:
#     name  age  salary
# 0  faize   20   15000
# 1   alan   25   16000
# 2   amiy   26   17000

# %%
voting = int(input("Enter your age"))
age = 18
if age>=18:
    print("you are eligible for voting")

else:
    print("you are under aged try againg next year")
# Out:
# Enter your age 20
# you are eligible for voting
